# %%
from wordcloud import WordCloud,STOPWORDS
#create stop words 
stopwords = set(STOPWORDS)
#call the wordcloud Constructor 
WC = WordCloud(stopwords=stopwords,max_words=25,background_color="white").generate('As you all know, You can never process text directly in Machine Learning . In order to achieve that You need to convert them into some vector. Word Embedding is just a technique to convert text into numeric form. There could be different techniques. This article will brief you on –  Word Embedding in Python through various ApproachesThis is one of the simplest technique in a word embedding. Here the complete vocabulary is converted into tokens .')

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams["figure.figsize"] = (10,5)
plt.imshow(WC)
plt.axis("off")
# plt.show()
plt.savefig('test.png')

# %%
import base64
def getWordcloud(content, uuid):
    WC = WordCloud(stopwords=stopwords,max_words=25,background_color="white").generate(content)
    plt.imshow(WC)
    plt.axis("off")
    # plt.show()
    filename = str(uuid)+'.png'
    plt.savefig(filename)
#     with open("test.png", "rb") as image_file:
#         encoded_string = base64.b64encode(image_file.read())
#     db.Article.update_one({
#       'uuid': uuid
#     },{
#       '$set': {
#         'wc': encoded_string
#       }
#     }, upsert=False)

# %%
import pymongo
from pymongo import MongoClient

# %%
client = MongoClient("mongodb+srv://omkar:Omkar%40123@cluster0.agvb0st.mongodb.net")

# %%
db = client['codecell_hackathon']

# %%
db
# Out:
# Database(MongoClient(host=['ac-mfj71oq-shard-00-01.agvb0st.mongodb.net:27017', 'ac-mfj71oq-shard-00-00.agvb0st.mongodb.net:27017', 'ac-mfj71oq-shard-00-02.agvb0st.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-nizu9q-shard-0', tls=True), 'codecell_hackathon')

# %%
import pandas as pd
df = pd.read_csv('scraping_big.csv')

# %%
for index, row in df.iterrows():
    if(index>763):
        a = str(row.content)
        u = row.uuid
        a = a.replace('"', '')
        a = a.replace("'", "")
        getWordcloud(a,u)
        print(index)
# Out:
# 764
# 765
# 766
# 767
# 768
# 769
# 770
# 771
# 772
# 773
# 774
# 775
# 776
# 777
# 778
# 779
# 780
# 781
# 782
# 783
# 784
# 785
# 786
# 787
# 788
# 789
# 790
# 791
# 792
# 793
# 794
# 795
# 796
# 797
# 798
# 799
# 800
# 801
# 802
# 803
# 804
# 805
# 806
# 807
# 808
# 809
# 810
# 811
# 812
# 813
# 814
# 815
# 816
# 817
# 818
# 819
# 820
# 821
# 822
# 823
# 824
# 825
# 826

# %%
import string
a = df.iloc[0]['content']
u = df.iloc[0]['uuid']
a = a.replace('"', '')
a = a.replace("'", "")
getWordcloud(a,u)

# %%
import pandas as pd
df = pd.read_csv('keywords.csv')

# %%
df
# Out:
#                                      uuid  \
# 0    0026af85-18b8-42a1-966a-17ac9d7ce9ea
# 1    026d11d8-98cb-4700-8fed-277eec712ba1
# 2    0217dc27-6c93-49f0-87ff-b8e83d959c7a
# 3    00bce962-4ca4-40e1-a869-7b25724acfbf
# 4    018d31cd-bf19-4afe-b71c-9d2d1cb163e6
# ..                                    ...
# 763  ffd68803-c869-4202-8ab0-74190d4356d1
# 764  fa86b42f-646b-42ce-896e-4939e94aa890
# 765  ffdc483a-91b0-4d5e-88db-9fcaa8aa9518
# 766  39a479c7-6efa-4bf4-a1a2-5880fb8e369d
# 767  53bc8f3f-31f2-4816-a4c1-c408b6ecd5b6
#
#                                                    url  \
# 0    https://www.rt.com/sport/552398-russian-gymnas...
# 1    https://www.rt.com/sport/552445-evgeny-rylov-s...
# 2    https://www.rt.com/sport/552931-russia-banned-...
# 3    https://sputniknews.com/20220319/are-bidens-af...
# 4    https://www.rt.com/news/552914-cyberattacks-uk...
# ..                                                 ...
# 763  https://sputniknews.com/20220329/russian-speci...
# 764  https://www.rt.com/russia/552285-donbass-russi...
# 765  https://www.rt.com/news/552652-pope-women-sanc...
# 766  https://www.rt.com/russia/552600-diplomats-pre...
# 767  https://www.rt.com/russia/553067-ukraine-biola...
#
#                                                  title  \
# 0    Russian ‘Z’ symbol gymnast speaks out over fea...
# 1    Olympic champion stripped of Speedo deal after...
# 2    Norway’s boycott of Russia caused safety fears...
# 3    Are Biden's Afghanistan & Ukraine Blunders Beh...
# 4                    Russia blames US for cyberattacks
# ..                                                 ...
# 763  Russian Special Forces Capture Ukrainian Natio...
# 764    Historic roots of the Donbass problem explained
# 765  Pope speaks against sanctions, calls for more ...
# 766  Experts warned for decades that NATO expansion...
# 767  Russia presents new evidence on Ukraine biolab...
#
#                                                  image  \
# 0    https://mf.b37mrtl.ru/files/2022.03/xxs/623884...
# 1    https://mf.b37mrtl.ru/files/2022.03/xxs/623987...
# 2    https://mf.b37mrtl.ru/files/2022.03/xxs/624342...
# 3    https://cdnn1.img.sputniknews.com/img/07e5/04/...
# 4    https://mf.b37mrtl.ru/files/2022.03/xxs/624310...
# ..                                                 ...
# 763  https://cdnn1.img.sputniknews.com/img/105096/8...
# 764  https://mf.b37mrtl.ru/files/2022.03/xxs/6235b3...
# 765  https://mf.b37mrtl.ru/files/2022.03/xxs/623cb9...
# 766  https://mf.b37mrtl.ru/files/2022.03/xxs/623c35...
# 767  https://mf.b37mrtl.ru/files/2022.03/xxs/62460a...
#
#                                               subtitle  \
# 0    Ivan Kuliak said he did ‘nothing wrong’, while...
# 1    Evgeny Rylov appeared at the event in Moscow l...
# 2    The Norwegian Ski Federation issued a blunt st...
# 3    On 16 March, The New York Times finally admitt...
# 4    Moscow repels hundreds of thousands of cyberat...
# ..                                                 ...
# 763  Earlier, a video was circulated on social medi...
# 764  The region has a distinct identity and doesn’t...
# 765  The Pontiff said women could convert power fro...
# 766  Analysts and diplomats have been saying since ...
# 767  Documents detail fate of US-funded deadly path...
#
#                                                content  \
# 0    Russian gymnast Ivan Kuliak insists he should ...
# 1    Swimwear company Speedo has terminated its spo...
# 2    Russian skiers feared for their safety at even...
# 3    "The NYT piece on Hunter Biden's laptop comes ...
# 4    The US and its allies have put together a grou...
# ..                                                 ...
# 763  Russian Special Forces have managed to detain ...
# 764  Originally published on March 19, 2022.Current...
# 765  Women must change the way society is governed,...
# 766  Russia’s military offensive in Ukraine has bee...
# 767  The Russian military has presented documents s...
#
#                                        lemmatized_text  \
# 0    Russian gymnast Ivan Kuliak insist he should n...
# 1    Swimwear company Speedo have terminate its spo...
# 2    Russian skiers fear for their safety at events...
# 3    "The NYT piece on Hunter Biden's laptop come a...
# 4    The US and its ally have put together a group ...
# ..                                                 ...
# 763  Russian Special Forces have manage to detain U...
# 764  Originally publish on March 19, 2022.Current e...
# 765  Women must change the way society be governed,...
# 766  Russia’s military offensive in Ukraine have be...
# 767  The Russian military have present document sho...
#
#                                               keywords  \
# 0    [('gymnast', 0.4213), ('gymnastics', 0.4113), ...
# 1    [('olympic', 0.4624), ('olympics', 0.434), ('r...
# 2    [('skiers', 0.5369), ('skiathlon', 0.535), ('s...
# 3    [('nyt', 0.4291), ('biden', 0.3542), ('msnbc',...
# 4    [('cyberattacks', 0.4585), ('moscow', 0.417), ...
# ..                                                 ...
# 763  [('russian', 0.409), ('ukrainians', 0.3996), (...
# 764  [('rus', 0.4088), ('donbass', 0.4049), ('donkr...
# 765  [('pope', 0.4754), ('governed', 0.3192), ('glo...
# 766  [('geopolitical', 0.379), ('putin', 0.355), ('...
# 767  [('drone', 0.3814), ('aerosolize', 0.3443), ('...
#
#                                                   keys  \
# 0    ['gymnast', 'gymnastics', 'kuliak', 'disqualif...
# 1    ['olympic', 'olympics', 'rylov', 'backstroke',...
# 2    ['skiers', 'skiathlon', 'ski', 'skiing', 'bols...
# 3    ['nyt', 'biden', 'msnbc', 'foia', '2024', 'yor...
# 4    ['cyberattacks', 'moscow', 'ukraine', 'terrori...
# ..                                                 ...
# 763  ['russian', 'ukrainians', 'perpetrators', 'put...
# 764  ['rus', 'donbass', 'donkrivbass', 'ukraine', '...
# 765  ['pope', 'governed', 'globalize', 'society', '...
# 766  ['geopolitical', 'putin', 'nato', 'crimea', 'u...
# 767  ['drone', 'aerosolize', 'kirillov', 'bayraktar...
#
#                                                   prob
# 0    [0.4213, 0.4113, 0.4111, 0.3481, 0.3159, 0.295...
# 1    [0.4624, 0.434, 0.4237, 0.4164, 0.4096, 0.3913...
# 2    [0.5369, 0.535, 0.5095, 0.4923, 0.4707, 0.426,...
# 3    [0.4291, 0.3542, 0.3114, 0.2748, 0.2646, 0.259...
# 4    [0.4585, 0.417, 0.4072, 0.407, 0.4022, 0.3871,...
# ..                                                 ...
# 763  [0.409, 0.3996, 0.3853, 0.3841, 0.3751, 0.3702...
# 764  [0.4088, 0.4049, 0.3923, 0.3805, 0.3794, 0.361...
# 765  [0.4754, 0.3192, 0.3147, 0.3147, 0.292, 0.2917...
# 766  [0.379, 0.355, 0.3463, 0.3385, 0.3338, 0.3197,...
# 767  [0.3814, 0.3443, 0.3352, 0.3007, 0.29, 0.2849,...
#
# [768 rows x 10 columns]

# %%
for index, row in df.iterrows():
    keys = row['keys']
    prob = row.prob
    uuid = row.uuid
    db.Article.update_one({
      'uuid': uuid
    },{
      '$set': {
        'keys': str(keys)
      }
    }, upsert=False)

# %%
db.Article.update_one({
      'uuid': uuid
    },{
      '$set': {
        'keywords': keywords
      }
    }, upsert=False)
# Out:
#                                      uuid  \
# 0    0026af85-18b8-42a1-966a-17ac9d7ce9ea
# 1    026d11d8-98cb-4700-8fed-277eec712ba1
# 2    0217dc27-6c93-49f0-87ff-b8e83d959c7a
# 3    00bce962-4ca4-40e1-a869-7b25724acfbf
# 4    018d31cd-bf19-4afe-b71c-9d2d1cb163e6
# ..                                    ...
# 763  ffd68803-c869-4202-8ab0-74190d4356d1
# 764  fa86b42f-646b-42ce-896e-4939e94aa890
# 765  ffdc483a-91b0-4d5e-88db-9fcaa8aa9518
# 766  39a479c7-6efa-4bf4-a1a2-5880fb8e369d
# 767  53bc8f3f-31f2-4816-a4c1-c408b6ecd5b6
#
#                                                    url  \
# 0    https://www.rt.com/sport/552398-russian-gymnas...
# 1    https://www.rt.com/sport/552445-evgeny-rylov-s...
# 2    https://www.rt.com/sport/552931-russia-banned-...
# 3    https://sputniknews.com/20220319/are-bidens-af...
# 4    https://www.rt.com/news/552914-cyberattacks-uk...
# ..                                                 ...
# 763  https://sputniknews.com/20220329/russian-speci...
# 764  https://www.rt.com/russia/552285-donbass-russi...
# 765  https://www.rt.com/news/552652-pope-women-sanc...
# 766  https://www.rt.com/russia/552600-diplomats-pre...
# 767  https://www.rt.com/russia/553067-ukraine-biola...
#
#                                                  title  \
# 0    Russian ‘Z’ symbol gymnast speaks out over fea...
# 1    Olympic champion stripped of Speedo deal after...
# 2    Norway’s boycott of Russia caused safety fears...
# 3    Are Biden's Afghanistan & Ukraine Blunders Beh...
# 4                    Russia blames US for cyberattacks
# ..                                                 ...
# 763  Russian Special Forces Capture Ukrainian Natio...
# 764    Historic roots of the Donbass problem explained
# 765  Pope speaks against sanctions, calls for more ...
# 766  Experts warned for decades that NATO expansion...
# 767  Russia presents new evidence on Ukraine biolab...
#
#                                                  image  \
# 0    https://mf.b37mrtl.ru/files/2022.03/xxs/623884...
# 1    https://mf.b37mrtl.ru/files/2022.03/xxs/623987...
# 2    https://mf.b37mrtl.ru/files/2022.03/xxs/624342...
# 3    https://cdnn1.img.sputniknews.com/img/07e5/04/...
# 4    https://mf.b37mrtl.ru/files/2022.03/xxs/624310...
# ..                                                 ...
# 763  https://cdnn1.img.sputniknews.com/img/105096/8...
# 764  https://mf.b37mrtl.ru/files/2022.03/xxs/6235b3...
# 765  https://mf.b37mrtl.ru/files/2022.03/xxs/623cb9...
# 766  https://mf.b37mrtl.ru/files/2022.03/xxs/623c35...
# 767  https://mf.b37mrtl.ru/files/2022.03/xxs/62460a...
#
#                                               subtitle  \
# 0    Ivan Kuliak said he did ‘nothing wrong’, while...
# 1    Evgeny Rylov appeared at the event in Moscow l...
# 2    The Norwegian Ski Federation issued a blunt st...
# 3    On 16 March, The New York Times finally admitt...
# 4    Moscow repels hundreds of thousands of cyberat...
# ..                                                 ...
# 763  Earlier, a video was circulated on social medi...
# 764  The region has a distinct identity and doesn’t...
# 765  The Pontiff said women could convert power fro...
# 766  Analysts and diplomats have been saying since ...
# 767  Documents detail fate of US-funded deadly path...
#
#                                                content  \
# 0    Russian gymnast Ivan Kuliak insists he should ...
# 1    Swimwear company Speedo has terminated its spo...
# 2    Russian skiers feared for their safety at even...
# 3    "The NYT piece on Hunter Biden's laptop comes ...
# 4    The US and its allies have put together a grou...
# ..                                                 ...
# 763  Russian Special Forces have managed to detain ...
# 764  Originally published on March 19, 2022.Current...
# 765  Women must change the way society is governed,...
# 766  Russia’s military offensive in Ukraine has bee...
# 767  The Russian military has presented documents s...
#
#                                        lemmatized_text  \
# 0    Russian gymnast Ivan Kuliak insist he should n...
# 1    Swimwear company Speedo have terminate its spo...
# 2    Russian skiers fear for their safety at events...
# 3    "The NYT piece on Hunter Biden's laptop come a...
# 4    The US and its ally have put together a group ...
# ..                                                 ...
# 763  Russian Special Forces have manage to detain U...
# 764  Originally publish on March 19, 2022.Current e...
# 765  Women must change the way society be governed,...
# 766  Russia’s military offensive in Ukraine have be...
# 767  The Russian military have present document sho...
#
#                                               keywords
# 0    [('gymnast', 0.4213), ('gymnastics', 0.4113), ...
# 1    [('olympic', 0.4624), ('olympics', 0.434), ('r...
# 2    [('skiers', 0.5369), ('skiathlon', 0.535), ('s...
# 3    [('nyt', 0.4291), ('biden', 0.3542), ('msnbc',...
# 4    [('cyberattacks', 0.4585), ('moscow', 0.417), ...
# ..                                                 ...
# 763  [('russian', 0.409), ('ukrainians', 0.3996), (...
# 764  [('rus', 0.4088), ('donbass', 0.4049), ('donkr...
# 765  [('pope', 0.4754), ('governed', 0.3192), ('glo...
# 766  [('geopolitical', 0.379), ('putin', 0.355), ('...
# 767  [('drone', 0.3814), ('aerosolize', 0.3443), ('...
#
# [768 rows x 8 columns]

# %%
import pandas as pd
df = pd.read_csv('scraping_big.csv')

# %%
df[df['uuid'] == 'a7108d1f-9419-4e89-bedd-f7cc9b0660f5']['content']
# Out:
# '533    Russian speakers in Germany are assaulted on a...'
